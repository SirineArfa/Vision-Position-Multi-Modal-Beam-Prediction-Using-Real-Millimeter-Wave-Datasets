# %%
# %cd /Users/rouna/OneDrive/Bureau/My_Files/AIM/tutore/Position-Beam-Prediction-main
# Out:
# C:\Users\rouna\OneDrive\Bureau\My_Files\AIM\tutore\Position-Beam-Prediction-main

# %%
# !python 2-normalize_split_train_test_plot.py
# Out:
# Traceback (most recent call last):
#   File "C:\Users\rouna\OneDrive\Bureau\My_Files\AIM\tutore\Position-Beam-Prediction-main\2-normalize_split_train_test_plot.py", line 16, in <module>
#     import train_test_func as func
#   File "C:\Users\rouna\OneDrive\Bureau\My_Files\AIM\tutore\Position-Beam-Prediction-main\train_test_func.py", line 9, in <module>
#     import utm
# ModuleNotFoundError: No module named 'utm'

# %%
# !pip install -r req.txt
# Out:
# ERROR: Invalid requirement: 'absl-py=0.13.0=py38haa95532_0' (from line 4 of req.txt)
# Hint: = is not a valid operator. Did you mean == ?

# %%
# !ls
# Out:
# 'ls' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex‚cutable ou un fichier de commandes.

# %%
import pandas as pd
import matplotlib.pyplot as plt

file = pd.read_csv('/Users/rouna/OneDrive/Bureau/My_Files/AIM/tutore/Position-Beam-Prediction-main/saved_folder/results/scenario 1 beams 64 norm 1 noise 0/KNN_N=5/1-runs_results_summary2.txt')
lines = file.plot.line(x='Top-k', y='average accuracy')
plt.title('KNN learning curves for scenario1')
plt.ylabel('Average Accuracy for beam prediction [%]')
plt.xlabel('Top-k')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

file = pd.read_csv('/Users/rouna/OneDrive/Bureau/My_Files/AIM/tutore/Position-Beam-Prediction-main/saved_folder/results/scenario 1 beams 64 norm 1 noise 0/LT_N=25/1-runs_results_summary - Copie.txt')
lines = file.plot.line(x='Top-k', y='average accuracy')
plt.title('Lookup Table learning curves for scenario1')
plt.ylabel('Average Accuracy for beam prediction [%]')
plt.xlabel('Top-k')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

file = pd.read_csv('/Users/rouna/OneDrive/Bureau/My_Files/AIM/tutore/Position-Beam-Prediction-main/saved_folder/results/1-runs_results_summary - Copie.txt')
lines = file.plot.line(x='Top-k', y=['average accuracy scenario1','average accuracy scenario2','average accuracy scenario3','average accuracy scenario4','average accuracy scenario5','average accuracy scenario6','average accuracy scenario7','average accuracy scenario8','average accuracy scenario9'])
plt.title('KNN learning curves for the 9 scenarios')
plt.ylabel('Average Accuracy for beam prediction [%]')
plt.xlabel('Top-k')
plt.show()
